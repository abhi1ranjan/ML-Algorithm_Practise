# %% [markdown]
# <a href="https://colab.research.google.com/github/abhi1ranjan/ML-Algorithm_Practise/blob/main/K_Means_Clustering_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# ___
# # K Means Clustering Project
#
# For this project we will attempt to use KMeans Clustering to cluster Universities into to two groups, Private and Public.
#
# ___
# It is **very important to note, we actually have the labels for this data set, but we will NOT use them for the KMeans clustering algorithm, since that is an unsupervised learning algorithm.**
#
# When using the Kmeans algorithm under normal circumstances, it is because you don't have labels. In this case we will use the labels to try to get an idea of how well the algorithm performed, but you won't usually do this for Kmeans, so the classification report and confusion matrix at the end of this project, don't truly make sense in a real world setting!.
# ___
#
# ## The Data
#
# We will use a data frame with 777 observations on the following 18 variables.
# * Private A factor with levels No and Yes indicating private or public university
# * Apps Number of applications received
# * Accept Number of applications accepted
# * Enroll Number of new students enrolled
# * Top10perc Pct. new students from top 10% of H.S. class
# * Top25perc Pct. new students from top 25% of H.S. class
# * F.Undergrad Number of fulltime undergraduates
# * P.Undergrad Number of parttime undergraduates
# * Outstate Out-of-state tuition
# * Room.Board Room and board costs
# * Books Estimated book costs
# * Personal Estimated personal spending
# * PhD Pct. of faculty with Ph.D.’s
# * Terminal Pct. of faculty with terminal degree
# * S.F.Ratio Student/faculty ratio
# * perc.alumni Pct. alumni who donate
# * Expend Instructional expenditure per student
# * Grad.Rate Graduation rate

# %% [markdown]
# ## Import Libraries
#
# ** Import the libraries you usually use for data analysis.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get the Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ** Read in the College_Data file using read_csv. Figure out how to set the first column as the index.**

# %%
CollegeData = pd.read_csv('/content/drive/MyDrive/ML Practice/Refactored_Py_DS_ML_Bootcamp-master/17-K-Means-Clustering/College_Data')

# %% [markdown]
# **Check the head of the data**

# %%
CollegeData.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# ** Check the info() and describe() methods on the data.**

# %%
CollegeData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   777 non-null    object
#  1   Private      777 non-null    object
#  2   Apps         777 non-null    int64
#  3   Accept       777 non-null    int64
#  4   Enroll       777 non-null    int64
#  5   Top10perc    777 non-null    int64
#  6   Top25perc    777 non-null    int64
#  7   F.Undergrad  777 non-null    int64
#  8   P.Undergrad  777 non-null    int64
#  9   Outstate     777 non-null    int64
#  10  Room.Board   777 non-null    int64
#  11  Books        777 non-null    int64
#  12  Personal     777 non-null    int64
#  13  PhD          777 non-null    int64
#  14  Terminal     777 non-null    int64
#  15  S.F.Ratio    777 non-null    float64
#  16  perc.alumni  777 non-null    int64
#  17  Expend       777 non-null    int64
#  18  Grad.Rate    777 non-null    int64
# ...

# %%
CollegeData.rename(columns={'Unnamed: 0': 'CollegeName'}, inplace=True)
CollegeData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CollegeName  777 non-null    object
#  1   Private      777 non-null    object
#  2   Apps         777 non-null    int64
#  3   Accept       777 non-null    int64
#  4   Enroll       777 non-null    int64
#  5   Top10perc    777 non-null    int64
#  6   Top25perc    777 non-null    int64
#  7   F.Undergrad  777 non-null    int64
#  8   P.Undergrad  777 non-null    int64
#  9   Outstate     777 non-null    int64
#  10  Room.Board   777 non-null    int64
#  11  Books        777 non-null    int64
#  12  Personal     777 non-null    int64
#  13  PhD          777 non-null    int64
#  14  Terminal     777 non-null    int64
#  15  S.F.Ratio    777 non-null    float64
#  16  perc.alumni  777 non-null    int64
#  17  Expend       777 non-null    int64
#  18  Grad.Rate    777 non-null    int64
# ...

# %%
CollegeData.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ## EDA
#
# It's time to create some data visualizations!
#
# ** Create a scatterplot of Grad.Rate versus Room.Board where the points are colored by the Private column. **

# %%
# Set the figure size
plt.figure(figsize=(10, 6))  # Adjust width and height as needed

sns.scatterplot(x=CollegeData['Room.Board'], y = CollegeData['Grad.Rate'], hue=CollegeData['Private'], palette='deep',s=25)

# Show the plot with a grid
plt.grid(True)
plt.show()

# %% [markdown]
# **Create a scatterplot of F.Undergrad versus Outstate where the points are colored by the Private column.**

# %%
# Set the figure size
plt.figure(figsize=(10, 6))  # Adjust width and height as needed

sns.scatterplot(x=CollegeData['Outstate'], y = CollegeData['F.Undergrad'], hue=CollegeData['Private'], palette='deep',s=25)

# Show the plot with a grid
plt.grid(True)
plt.show()

# %% [markdown]
# ** Create a stacked histogram showing Out of State Tuition based on the Private column. Try doing this using [sns.FacetGrid](https://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.FacetGrid.html). If that is too tricky, see if you can do it just by using two instances of pandas.plot(kind='hist'). **

# %%
# Set the figure size
plt.figure(figsize=(10, 6))  # Adjust width and height as needed

sns.set_style('darkgrid')
g = sns.FacetGrid(data=CollegeData, hue='Private',height=6, aspect=1.5)
g = g.map(plt.hist,'Outstate',bins=40,alpha=0.7)

# %%
#### --------------- using pandas library---------------- ###
# Filter data by Private column
public_data = CollegeData[CollegeData['Private'] == 'No']
private_data = CollegeData[CollegeData['Private'] == 'Yes']

# Set the figure size
plt.figure(figsize=(10, 6))

# Plot histograms for each subset, with transparency for overlaying
public_data['Outstate'].plot(kind='hist', bins=40, alpha=0.5, label='Public', color='orange')
private_data['Outstate'].plot(kind='hist', bins=40, alpha=0.5, label='Private', color='purple')

# Add labels and legend
plt.xlabel('Outstate')
plt.ylabel('Frequency')
plt.title('Outstate Tuition for Public vs Private Colleges')
plt.legend()

plt.show()

# %% [markdown]
# **Create a similar histogram for the Grad.Rate column.**

# %%
# Set the figure size
plt.figure(figsize=(10, 6))  # Adjust width and height as needed

sns.set_style('darkgrid')
g = sns.FacetGrid(data=CollegeData, hue='Private',height=6, aspect=1.5)
g = g.map(plt.hist,'Grad.Rate',bins=20,alpha=0.7)

# %%
# Set the figure size
plt.figure(figsize=(10, 6))  # Adjust width and height as needed

sns.set_style('darkgrid')
g = sns.FacetGrid(data=CollegeData, hue='Private',height=6, aspect=1.5)
g = g.map(plt.hist,'Grad.Rate',bins=40,alpha=0.8)

# %% [markdown]
# ** Notice how there seems to be a private school with a graduation rate of higher than 100%.What is the name of that school?**

# %%
CollegeData[CollegeData['Grad.Rate']>100]
# Out:
#            Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# 95  Cazenovia College     Yes  3847    3433     527          9         35
#
#     F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 95         1010           12      9384        4840    600       500   22
#
#     Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 95        47       14.3           20    7697        118

# %% [markdown]
# ** Set that school's graduation rate to 100 so it makes sense. You may get a warning not an error) when doing this operation, so use dataframe operations or just re-do the histogram visualization to make sure it actually went through.**

# %%
# CollegeData['Grad.Rate']['Cazenovia College'] = 100 - this shows warning and value doesnot get updated.
CollegeData.loc[95, "Grad.Rate"] = 100

# %%
CollegeData[CollegeData['Grad.Rate']>100]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Private, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate]
# Index: []

# %%
# Set the figure size
plt.figure(figsize=(10, 6))  # Adjust width and height as needed

sns.set_style('darkgrid')
g = sns.FacetGrid(data=CollegeData, hue='Private',height=6, aspect=1.5)
g = g.map(plt.hist,'Grad.Rate',bins=40,alpha=0.8)

# %% [markdown]
# ## K Means Cluster Creation
#
# Now it is time to create the Cluster labels!

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# Creating an instance of a K Means model with 2 clusters.

# %%
kmeans = KMeans(n_clusters=2)

# %% [markdown]
# **Fit the model to all the data except for the Private label.**

# %%
# Drop non-numeric columns (e.g., college names) and encode 'Private'
CollegeData_numeric = CollegeData.drop(['CollegeName'], axis=1)  # replace 'CollegeName' with your actual column name if different
CollegeData_numeric['Private'] = LabelEncoder().fit_transform(CollegeData['Private'])

# Define and fit the KMeans model
kmeans = KMeans(n_clusters=2)
kmeans.fit(CollegeData_numeric)
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# Getting the cluster center vectors.

# %%
kmeans.cluster_centers_
# Out:
# array([[7.93721973e-01, 1.81323468e+03, 1.28716592e+03, 4.91044843e+02,
#         2.53094170e+01, 5.34708520e+01, 2.18854858e+03, 5.95458894e+02,
#         1.03957085e+04, 4.31136472e+03, 5.41982063e+02, 1.28033632e+03,
#         7.04424514e+01, 7.78251121e+01, 1.40997010e+01, 2.31748879e+01,
#         8.93204634e+03, 6.50926756e+01],
#        [3.14814815e-01, 1.03631389e+04, 6.55089815e+03, 2.56972222e+03,
#         4.14907407e+01, 7.02037037e+01, 1.30619352e+04, 2.46486111e+03,
#         1.07191759e+04, 4.64347222e+03, 5.95212963e+02, 1.71420370e+03,
#         8.63981481e+01, 9.13333333e+01, 1.40277778e+01, 2.00740741e+01,
#         1.41705000e+04, 6.75925926e+01]])

# %% [markdown]
# ## Evaluation
#
# There is no perfect way to evaluate clustering if you don't have the labels, however we do have the labels, so we take advantage of this to evaluate our clusters, keep in mind, you usually won't have this luxury in the real world.
#
# *** Creating a new column for CollegeData called 'Cluster', which is a 1 for a Private school, and a 0 for a public school.**

# %%
def converter(cluster):
    if cluster=='Yes':
        return 1
    else:
        return 0

# %%
CollegeData['Cluster'] = CollegeData['Private'].apply(converter)

# %%
CollegeData.head()
# Out:
#                     CollegeName Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# ** Create a confusion matrix and classification report to see how well the Kmeans clustering worked without being given any labels.**

# %%
print(classification_report(CollegeData['Cluster'], kmeans.labels_))
print(confusion_matrix(CollegeData['Cluster'], kmeans.labels_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.21      0.65      0.31       212
#            1       0.31      0.06      0.10       565
#
#     accuracy                           0.22       777
#    macro avg       0.26      0.36      0.21       777
# weighted avg       0.29      0.22      0.16       777
#
# [[138  74]
#  [531  34]]

# %% [markdown]
# Not so bad considering the algorithm is purely using the features to cluster the universities into 2 distinct groups!
